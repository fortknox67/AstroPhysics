# %%
import numpy as np
import matplotlib.pyplot as plt



def saha (T):

    return ((((1.79844*(10**14))*T)**(3/2))/(10**20))*(np.exp(-157827.55/T))

T = np.linspace(1,50000)

y = plt.plot(T,saha(T))
plt.xlabel("temperature (K)")
plt.ylabel("ratio of ionized hydrogen")
# Out:
# Text(0,0.5,'ratio of ionized hydrogen')

# %%
def boltzmann (T):

    return (1/4)*np.exp(-118370/T)

T = np.linspace(1,50000)

x = plt.plot(T,boltzmann(T))
plt.xlabel("temperature (K)")
plt.ylabel("ratio of excited state hydrogen")
# Out:
# Text(0,0.5,'ratio of excited state hydrogen')

# %%
def answer (T):

    return (boltzmann(T)*(1/(1+saha(T))))

T = np.linspace(1,50000)

z = plt.plot(T,answer(T))
plt.xlabel("temperature (K)")
plt.ylabel("first excited state hydrogen")
# Out:
# Text(0,0.5,'first excited state hydrogen')

# %%
#In relation to questions 3 and 4 in homework 6:
#Question 3 was about arranging the amount of hydrogen lines visible in different star types with A type stars
#having the most visible hydrogen lines with the visibility of the hydrogen lines dropping off as you go to hotter 
#or colder stars with the amount dropping much more quickly towards the hotter stars.
#This data matches very clearly with our graph of the fraction of hyrogen in the first excited state
# with the temperature of A type stars being around 10,000 K and our graph peaking around the same number

# Question 4 however asked the temperature required to have enough kinetic energy to get the majority of hydrogen atoms 
# to the first excited state and the temperature required was much higher than this. This likely means that there is
# some other physical phenomena making it possible for these hydrogen atoms to get to the first excited state at a
# much lower temperature than expected. I would imagine that this phenomena is quantum tunneling.
